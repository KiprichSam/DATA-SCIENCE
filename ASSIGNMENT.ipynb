# %% [markdown]
# <a href="https://colab.research.google.com/github/KiprichSam/DATA-SCIENCE/blob/main/ASSIGNMENT.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
## DSA 6101
# PRINCIPLES OF DATA SCIENCE
# SAMSON KIPCHIRCHIR
# 25/03065

# %% [markdown]
# ### **1. What is the role of a programming environment like Jupyter or RStudio in data science workflows?**

# %% [markdown]
# These tools provide user-friendly integrated development environment and workflow tools to analyze, process and visualize data where users can collaborate, debug and share amongst peers.

# %% [markdown]
# # **2. Compare Anaconda with pip/virtualenv for managing environments and packages?**

# %% [markdown]
# 1. Scope - Anaconda is cross-language supporting Python, R, C/C++ and supports system dependencies whereas pip/virtualenv supports Python-specific packages.
#
# 2. Dependency Resolution - Anaconda is robust resolving conflicts within all types of packages whereas pip/virtualenv is language-specific primarily for Python packages.
#
# 3. Use Cases - Anaconda is suitable in Data science, machine learning and scientific computing whereas pip/virtualenv is suitable in Web development and general Python projects

# %% [markdown]
# ## *3. Why is version control important in collaborative data science projects?**

# %% [markdown]
# Version control plays a role as it enhances collaboration and teamwork where a group of peers can collaborate on one project handling different parts of the project simultaneously, allowing error recovery and experimentation as one can rollback to previous stable version incase of a bug or retracing steps.
#
# It also provides clear audit trails as each commit made has an accompanying commit message detailing the changes and why creating a transparent history. It also offers a platform for branching and merging and allows code review where peers can review each other’s code before it is integrated into the main branch.

# %% [markdown]
# ## **4. What are the key differences between Jupyter Notebook and JupyterLab?** *italicised text*

# %% [markdown]
# 1. Jupyter Notebook has a simple, linear interface where each notebook opens in its own new browser tab focusing on single notebook document at a time whereas JupyterLab offers a multi-document interface (MDI) within a single browser tab providing a flexible, integrated workspace where you can open multiple notebooks, code consoles, text editors, terminals, and even display output views.
#
# 2. JupyterLab is slightly heavier and more resource-intensive due to its more complex interface and integrated features, especially with many tabs or panels open as compared to Jupyter Notebook.
#
# 3. Jupyter Notebook is mainly limited to working with .ipynb files, whereas JupyterLab supports a variety of file types such as Python scripts, Markdown, CSVs, and JSON files in one integrated workspace.
#
# 4. Jupyter Notebook is lightweight and beginner-friendly with a minimal interface, while JupyterLab offers a more powerful, IDE-like environment that is customizable and better suited for advanced workflows.

# %% [markdown]
# ## **5. Explain how Git and GitHub work together. What is a pull request and when is it used?**

# %% [markdown]
# Git is a version control system that is installed and running locally on your machine primarily tracking file changes, managing different versions of a project, and allowing multiple people to work on the same project without overwriting each other's work.
#
# GitHub is a web-based hosting service for Git repositories. While Git handles the mechanics of version control on your local machine, GitHub provides a centralized, cloud-based platform where you can store your Git repositories.
#
# GitHub adds a layer of collaborative tools, a graphical user interface (GUI), and social features on top of Git, making it much easier for teams to work together.
#
# A pull request is a formal proposal to merge a set of changes from one branch into another branch in a Git repository.
# Pull requests are used in almost any collaborative software development or data science project that uses Git and a hosting service like GitHub.

# %% [markdown]
# ## **6. Set up a conda environment named datasci_env and install pandas and matplotlib in it.**

# %% [markdown]
# ![Screenshot (16).png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot (18).png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot (19).png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot (20).png](data:image/png;base64,...)

# %% [markdown]
# ## **7. Initialize a Git repository in a local project folder and push it to a GitHub repository.**

# %% [markdown]
# ![Screenshot (31).png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot (32).png](data:image/png;base64,...)

# %% [markdown]
# # **8. Open Google Colab, write a simple Python script that imports pandas, reads a CSV file, and displays the first five rows.**

# %%
import pandas as pd

# %%
data=pd.read_csv('https://raw.githubusercontent.com/CourseMaterial/DataWrangling/main/flowerdataset.csv', header="infer")

# %%
data.head(5)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa
